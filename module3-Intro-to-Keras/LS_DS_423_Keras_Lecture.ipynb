# %% [markdown]
# Lambda School Data Science
#
# *Unit 4, Sprint 2, Module 3*
#
# ---

# %% [markdown]
# # Neural Network Frameworks (Prepare)

# %% [markdown]
# ## Learning Objectives
# * <a href="#p1">Part 1</a>: Learn How to Select Model Architecture
# * <a href="#p2">Part 2</a>: Discuss the trade-off between various activation functions
# * <a href="#p3">Part 3</a>: Regularization Strategies
#
# ## Lets Use Libraries!
#
# The objective of the last two days has been to familiarize you with the fundamentals of neural networks: terminology, structure of networks, forward propagation, error/cost functions, backpropagation, epochs, and gradient descent. We have tried to reinforce these topics by requiring to you code some of the simplest neural networks by hand including Perceptrons (single node neural networks) and Multi-Layer Perceptrons also known as Feed-Forward Neural Networks. Continuing to do things by hand would not be the best use of our limited time. You're ready to graduate from doing things by hand and start using some powerful libraries to build cutting-edge predictive models.

# %% [markdown]
# # Choosing Architecture (Learn)

# %% [markdown]
# ## Overview
#
# Choosing an architecture for a neural network is almost more an art than a science. The best way to choose an architecture is through research and experimentation.
#
# Let's do a few experiments, and track our results using a tool called TensorBoard which is a way to interactively visualize the results of our various experiences. Here is our previous model with TensorBoard incorporated:

# %%
# %pwd

# %%
from tensorflow.keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# %load_ext tensorboard

import os
import datetime
import tensorflow as tf

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
    Flatten(),
    Dense(10, input_dim=784, activation="softmax")
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x=X_train, 
        y=y_train, 
        epochs=5, 
        validation_data=(X_test, y_test), 
        callbacks=[tensorboard_callback])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 10.2197 - accuracy: 0.8383 - val_loss: 5.5940 - val_accuracy: 0.8778
# Epoch 2/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 6.0403 - accuracy: 0.8776 - val_loss: 6.1736 - val_accuracy: 0.8772
# Epoch 3/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 5.7402 - accuracy: 0.8827 - val_loss: 5.0767 - val_accuracy: 0.8990
# Epoch 4/5
# 1875/1875 [==============================] - 2s 1ms/step - loss: 5.5178 - accuracy: 0.8845 - val_loss: 4.8391 - val_accuracy: 0.9007
# Epoch 5/5
# 1875/1875 [==============================] - 3s 1ms/step - loss: 5.4105 - accuracy: 0.8860 - val_loss: 6.4606 - val_accuracy: 0.8670

# %%
# %tensorboard --logdir logs
# Out:
# Launching TensorBoard...

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense

model = Sequential([
    Flatten(),
    Dense(50, activation='sigmoid'),
    Dense(10, input_dim=784, activation="softmax")
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x=X_train,
        y=y_train,
        epochs=50,
        validation_data=(X_test, y_test),
        callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.6508 - accuracy: 0.8257 - val_loss: 0.4063 - val_accuracy: 0.8815
# Epoch 2/50
# 1875/1875 [==============================] - 2s 1ms/step - loss: 0.4081 - accuracy: 0.8815 - val_loss: 0.3693 - val_accuracy: 0.8915
# Epoch 3/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3729 - accuracy: 0.8882 - val_loss: 0.3408 - val_accuracy: 0.9011
# Epoch 4/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3581 - accuracy: 0.8909 - val_loss: 0.3217 - val_accuracy: 0.9052
# Epoch 5/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3401 - accuracy: 0.8966 - val_loss: 0.3327 - val_accuracy: 0.8978
# Epoch 6/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3254 - accuracy: 0.9014 - val_loss: 0.3154 - val_accuracy: 0.9044
# Epoch 7/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3086 - accuracy: 0.9062 - val_loss: 0.3038 - val_accuracy: 0.9083
# Epoch 8/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.3106 - accuracy: 0.9054 - val_loss: 0.3000 - val_accuracy: 0.9104
# Epoch 9/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2975 - accuracy: 0.9103 - val_loss: 0.2867 - val_accuracy: 0.9142
# Epoch 10/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2847 - accuracy: 0.9137 - val_loss: 0.2831 - val_accuracy: 0.9145
# Epoch 11/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2769 - accuracy: 0.9176 - val_loss: 0.2858 - val_accuracy: 0.9152
# Epoch 12/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2725 - accuracy: 0.9181 - val_loss: 0.2809 - val_accuracy: 0.9135
# Epoch 13/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2706 - accuracy: 0.9186 - val_loss: 0.2831 - val_accuracy: 0.9110
# Epoch 14/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2666 - accuracy: 0.9195 - val_loss: 0.2664 - val_accuracy: 0.9216
# Epoch 15/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2599 - accuracy: 0.9215 - val_loss: 0.2534 - val_accuracy: 0.9255
# Epoch 16/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2518 - accuracy: 0.9233 - val_loss: 0.2542 - val_accuracy: 0.9212
# Epoch 17/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2531 - accuracy: 0.9225 - val_loss: 0.2467 - val_accuracy: 0.9265
# Epoch 18/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2547 - accuracy: 0.9238 - val_loss: 0.2580 - val_accuracy: 0.9221
# Epoch 19/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2450 - accuracy: 0.9262 - val_loss: 0.2521 - val_accuracy: 0.9218
# Epoch 20/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2413 - accuracy: 0.9278 - val_loss: 0.2403 - val_accuracy: 0.9282
# Epoch 21/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2348 - accuracy: 0.9295 - val_loss: 0.2528 - val_accuracy: 0.9247
# Epoch 22/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2500 - accuracy: 0.9261 - val_loss: 0.2421 - val_accuracy: 0.9277
# Epoch 23/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2370 - accuracy: 0.9286 - val_loss: 0.2464 - val_accuracy: 0.9270
# Epoch 24/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2338 - accuracy: 0.9296 - val_loss: 0.2342 - val_accuracy: 0.9322
# Epoch 25/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2301 - accuracy: 0.9312 - val_loss: 0.2324 - val_accuracy: 0.9307
# Epoch 26/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2251 - accuracy: 0.9327 - val_loss: 0.2250 - val_accuracy: 0.9339
# Epoch 27/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2217 - accuracy: 0.9321 - val_loss: 0.2361 - val_accuracy: 0.9292
# Epoch 28/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2187 - accuracy: 0.9340 - val_loss: 0.2173 - val_accuracy: 0.9364
# Epoch 29/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2221 - accuracy: 0.9331 - val_loss: 0.2479 - val_accuracy: 0.9237
# Epoch 30/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2378 - accuracy: 0.9276 - val_loss: 0.2416 - val_accuracy: 0.9242
# Epoch 31/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2324 - accuracy: 0.9305 - val_loss: 0.2238 - val_accuracy: 0.9322
# Epoch 32/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2215 - accuracy: 0.9327 - val_loss: 0.2182 - val_accuracy: 0.9342
# Epoch 33/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2176 - accuracy: 0.9338 - val_loss: 0.2211 - val_accuracy: 0.9336
# Epoch 34/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2204 - accuracy: 0.9332 - val_loss: 0.2208 - val_accuracy: 0.9342
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2236 - accuracy: 0.9324 - val_loss: 0.2346 - val_accuracy: 0.9263
# Epoch 36/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2215 - accuracy: 0.9321 - val_loss: 0.2250 - val_accuracy: 0.9325
# Epoch 37/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2230 - accuracy: 0.9332 - val_loss: 0.2211 - val_accuracy: 0.9327
# Epoch 38/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2128 - accuracy: 0.9357 - val_loss: 0.2431 - val_accuracy: 0.9270
# Epoch 39/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2130 - accuracy: 0.9354 - val_loss: 0.2229 - val_accuracy: 0.9350
# Epoch 40/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2151 - accuracy: 0.9366 - val_loss: 0.2103 - val_accuracy: 0.9373
# Epoch 41/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2140 - accuracy: 0.9370 - val_loss: 0.2235 - val_accuracy: 0.9330
# Epoch 42/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2189 - accuracy: 0.9342 - val_loss: 0.2150 - val_accuracy: 0.9344
# Epoch 43/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2148 - accuracy: 0.9348 - val_loss: 0.2129 - val_accuracy: 0.9382
# Epoch 44/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2102 - accuracy: 0.9371 - val_loss: 0.2124 - val_accuracy: 0.9336
# Epoch 45/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2029 - accuracy: 0.9389 - val_loss: 0.2079 - val_accuracy: 0.9398
# Epoch 46/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.1990 - accuracy: 0.9401 - val_loss: 0.2140 - val_accuracy: 0.9352
# Epoch 47/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2071 - accuracy: 0.9379 - val_loss: 0.2078 - val_accuracy: 0.9358
# Epoch 48/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2098 - accuracy: 0.9369 - val_loss: 0.2167 - val_accuracy: 0.9343
# Epoch 49/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2094 - accuracy: 0.9369 - val_loss: 0.2131 - val_accuracy: 0.9368
# Epoch 50/50
# 1875/1875 [==============================] - 3s 1ms/step - loss: 0.2023 - accuracy: 0.9391 - val_loss: 0.1982 - val_accuracy: 0.9447

# %%
# model = Sequential([
#     Flatten(),
#     Dense(100, activation='relu'),
#     Dense(10, input_dim=784, activation="softmax")
# ])

model = Sequential([
    Flatten(),
    Dense(78, activation="relu"),
    Dense(39, activation="relu"),
    Dense(39, activation="relu"),
    Dense(19, activation='swish'),
    Dense(19, activation='swish'),
    Dense(19, activation='swish'),
    Dense(10, input_dim=784, activation="softmax"),
])

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(x=X_train,
        y=y_train,
        epochs=50,
        validation_data=(X_test, y_test),
        callbacks=[tensorboard_callback])
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6118 - accuracy: 0.8228 - val_loss: 0.2951 - val_accuracy: 0.9245
# Epoch 2/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2269 - accuracy: 0.9379 - val_loss: 0.2092 - val_accuracy: 0.9456
# Epoch 3/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1753 - accuracy: 0.9517 - val_loss: 0.1887 - val_accuracy: 0.9537
# Epoch 4/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1450 - accuracy: 0.9607 - val_loss: 0.1510 - val_accuracy: 0.9591
# Epoch 5/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1209 - accuracy: 0.9665 - val_loss: 0.1497 - val_accuracy: 0.9621
# Epoch 6/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.1040 - accuracy: 0.9717 - val_loss: 0.1324 - val_accuracy: 0.9652
# Epoch 7/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0952 - accuracy: 0.9741 - val_loss: 0.1194 - val_accuracy: 0.9693
# Epoch 8/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0828 - accuracy: 0.9771 - val_loss: 0.1042 - val_accuracy: 0.9735
# Epoch 9/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0744 - accuracy: 0.9793 - val_loss: 0.1496 - val_accuracy: 0.9659
# Epoch 10/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0702 - accuracy: 0.9802 - val_loss: 0.1150 - val_accuracy: 0.9718
# Epoch 11/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0634 - accuracy: 0.9822 - val_loss: 0.1113 - val_accuracy: 0.9729
# Epoch 12/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0582 - accuracy: 0.9837 - val_loss: 0.1382 - val_accuracy: 0.9683
# Epoch 13/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0519 - accuracy: 0.9853 - val_loss: 0.1318 - val_accuracy: 0.9708
# Epoch 14/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0487 - accuracy: 0.9868 - val_loss: 0.1135 - val_accuracy: 0.9745
# Epoch 15/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0461 - accuracy: 0.9872 - val_loss: 0.1145 - val_accuracy: 0.9733
# Epoch 16/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0467 - accuracy: 0.9869 - val_loss: 0.1223 - val_accuracy: 0.9752
# Epoch 17/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0393 - accuracy: 0.9890 - val_loss: 0.1379 - val_accuracy: 0.9749
# Epoch 18/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0398 - accuracy: 0.9891 - val_loss: 0.1706 - val_accuracy: 0.9695
# Epoch 19/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0386 - accuracy: 0.9894 - val_loss: 0.1333 - val_accuracy: 0.9730
# Epoch 20/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0376 - accuracy: 0.9902 - val_loss: 0.1122 - val_accuracy: 0.9763
# Epoch 21/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0321 - accuracy: 0.9911 - val_loss: 0.1438 - val_accuracy: 0.9750
# Epoch 22/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0326 - accuracy: 0.9907 - val_loss: 0.1181 - val_accuracy: 0.9769
# Epoch 23/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0354 - accuracy: 0.9903 - val_loss: 0.1207 - val_accuracy: 0.9785
# Epoch 24/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0293 - accuracy: 0.9919 - val_loss: 0.1530 - val_accuracy: 0.9742
# Epoch 25/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0295 - accuracy: 0.9919 - val_loss: 0.1301 - val_accuracy: 0.9752
# Epoch 26/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0278 - accuracy: 0.9924 - val_loss: 0.1147 - val_accuracy: 0.9760
# Epoch 27/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0302 - accuracy: 0.9919 - val_loss: 0.1368 - val_accuracy: 0.9748
# Epoch 28/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0253 - accuracy: 0.9929 - val_loss: 0.1328 - val_accuracy: 0.9778
# Epoch 29/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0250 - accuracy: 0.9935 - val_loss: 0.1408 - val_accuracy: 0.9773
# Epoch 30/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0271 - accuracy: 0.9930 - val_loss: 0.1366 - val_accuracy: 0.9767
# Epoch 31/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0237 - accuracy: 0.9940 - val_loss: 0.1574 - val_accuracy: 0.9758
# Epoch 32/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0230 - accuracy: 0.9942 - val_loss: 0.1583 - val_accuracy: 0.9752
# Epoch 33/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0242 - accuracy: 0.9937 - val_loss: 0.1434 - val_accuracy: 0.9776
# Epoch 34/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0226 - accuracy: 0.9944 - val_loss: 0.1419 - val_accuracy: 0.9762
# Epoch 35/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0240 - accuracy: 0.9938 - val_loss: 0.1423 - val_accuracy: 0.9762
# Epoch 36/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.1694 - val_accuracy: 0.9726
# Epoch 37/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0233 - accuracy: 0.9939 - val_loss: 0.1523 - val_accuracy: 0.9779
# Epoch 38/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0189 - accuracy: 0.9952 - val_loss: 0.1677 - val_accuracy: 0.9768
# Epoch 39/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0195 - accuracy: 0.9950 - val_loss: 0.1623 - val_accuracy: 0.9755
# Epoch 40/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0213 - accuracy: 0.9944 - val_loss: 0.1523 - val_accuracy: 0.9775
# Epoch 41/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0155 - accuracy: 0.9958 - val_loss: 0.1800 - val_accuracy: 0.9741
# Epoch 42/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0206 - accuracy: 0.9947 - val_loss: 0.1666 - val_accuracy: 0.9735
# Epoch 43/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0188 - accuracy: 0.9956 - val_loss: 0.1941 - val_accuracy: 0.9695
# Epoch 44/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0170 - accuracy: 0.9955 - val_loss: 0.2198 - val_accuracy: 0.9760
# Epoch 45/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0202 - accuracy: 0.9951 - val_loss: 0.1574 - val_accuracy: 0.9780
# Epoch 46/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0176 - accuracy: 0.9958 - val_loss: 0.1789 - val_accuracy: 0.9727
# Epoch 47/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0176 - accuracy: 0.9961 - val_loss: 0.1996 - val_accuracy: 0.9759
# Epoch 48/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0193 - accuracy: 0.9957 - val_loss: 0.1483 - val_accuracy: 0.9750
# Epoch 49/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0196 - accuracy: 0.9955 - val_loss: 0.1396 - val_accuracy: 0.9772
# Epoch 50/50
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0159 - accuracy: 0.9960 - val_loss: 0.1691 - val_accuracy: 0.9777

# %% [markdown]
# ## Follow Along
#
# Let's run a couple of experiments in groups based on your birthday:
# 1. Jan - March:  Try adding an additional layer to the model
# 2. April - June: Add 2 hidden layers with identical number of neurons
# 3. July - Sept: Change the activation functions in the hidden layers (used as many layers as you want)
# 4. Oct - December: Try changing the optimization function and use any architecture that you want.

# %% [markdown]
# ### Additional Hidden Layer

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ### 2 Additional Hidden Layers

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ### Different Activation Functions

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ### Different Optimization Functions

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ## Challenge
#
# You will have to choose your own architectures in today's module project. In the next module, we will discuss hyperparameter optimization which can help you handle these numerous choices.
#
# ---

# %% [markdown]
# # Activation Functions (Learn)

# %% [markdown]
# ## Overview
# What is an activation function and how does it work?
#
# - Takes in a weighted sum of inputs + a bias from the previous layer and outputs an "activation" value.
# - Based its inputs the neuron decides how 'activated' it should be. This can be thought of as the neuron deciding how strongly to fire. You can also think of it as if the neuron is deciding how much of the signal that it has received to pass onto the next layer.
# - Our choice of activation function does not only affect signal that is passed forward but also affects the backpropagation algorithm. It affects how we update weights in reverse order since activated weight/input sums become the inputs of the next layer.

# %% [markdown]
# ## Follow Along

# %% [markdown]
# ### Step Function
#
# ![Heaviside Step Function](https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/Dirac_distribution_CDF.svg/2560px-Dirac_distribution_CDF.svg.png)
#
# All or nothing, a little extreme, which is fine, but makes updating weights through backpropagation impossible. Why? remember that during backpropagation we use derivatives in order to determine how much to update or not update weights. What is the derivative of the step function?

# %% [markdown]
# ### Linear Function
#
# ![Linear Function](http://www.roconnell.net/Parent%20function/linear.gif)
#
# The linear function takes the opposite tact from the step function and passes the signal onto the next layer by a constant factor. There are problems with this but the biggest problems again lie in backpropagation. The derivative of any linear function is a horizontal line which would indicate that we should update all weights by a constant amount every time -which on balance wouldn't change the behavior of our network. Linear functions are typically only used for very simple tasks where interpretability is important, but if interpretability is your highest priority, you probably shouldn't be using neural networks in the first place.

# %% [markdown]
# ### Sigmoid Function
#
# ![Sigmoid Function](https://upload.wikimedia.org/wikipedia/commons/thumb/8/88/Logistic-curve.svg/480px-Logistic-curve.svg.png)
#
# The sigmoid function works great as an activation function! it's continuously differentiable, its derivative doesn't have a constant slope, and having the higher slope in the middle pushes y value predictions towards extremes which is particularly useful for binary classification problems. I mean, this is why we use it as the squishifier in logistic regression as well. It constrains output, but over repeated epochs pushes predictions towards a strong binary prediction.
#
# What's the biggest problem with the sigmoid function? The fact that its slope gets pretty flat so quickly after its departure from zero. This means that updating weights based on its gradient really diminishes the size of our weight updates as our model gets more confident about its classifications. This is why even after so many iterations with our test score example we couldn't reach the levels of fit that our gradient descent based model could reach in just a few epochs.

# %% [markdown]
# ### Tanh Function
#
# ![Tanh Function](http://mathworld.wolfram.com/images/interactive/TanhReal.gif)
#
# What if the sigmoid function didn't get so flat quite as soon when moving away from zero and was a little bit steeper in the middle? That's basically the Tanh function. The Tanh function can actually be created by scaling the sigmoid function by 2 in the y dimension and subtracting 1 from all values. It has basically the same properties as the sigmoid, still struggles from diminishingly flat gradients as we move away from 0, but its derivative is higher around 0 causing weights to move to the extremes a little faster.

# %% [markdown]
# ### ReLU Function
#
# ![ReLU Function](https://cdn-images-1.medium.com/max/937/1*oePAhrm74RNnNEolprmTaQ.png)
#
# ReLU stands for Rectified Linear Units it is by far the most commonly used activation function in modern neural networks. It doesn't activate neurons that are being passed a negative signal and passes on positive signals. Think about why this might be useful. Remember how a lot of our initial weights got set to negative numbers by chance? This would have dealt with those negative weights a lot faster than the sigmoid function updating. What does the derivative of this function look like? It looks like the step function! This means that not all neurons are activated. With sigmoid basically all of our neurons are passing some amount of signal even if it's small making it hard for the network to differentiate important and less important connections. ReLU turns off a portion of our less important neurons which decreases computational load, but also helps the network learn what the most important connections are faster.
#
# What's the problem with relu? Well the left half of its derivative function shows that for neurons that are initialized with weights that cause them to have no activation, our gradient will not update those neuron's weights, this can lead to dead neurons that never fire and whose weights never get updated. We would probably want to update the weights of neurons that didn't fire even if it's just by a little bit in case we got unlucky with our initial weights and want to give those neurons a chance of turning back on in the future.

# %% [markdown]
# ### Leaky ReLU
#
# ![Leaky ReLU](https://cdn-images-1.medium.com/max/1600/1*ypsvQH7kvtI2BhzR2eT_Sw.png)
#
# Leaky ReLU accomplishes exactly that! it avoids having a gradient of 0 on the left side of its derivative function. This means that even "dead" neurons have a chance of being revived over enough iterations. In some specifications the slope of the leaky left-hand side can also be experimented with as a hyperparameter of the model!

# %% [markdown]
# ### Softmax Function
#
# ![Softmax Function](https://cdn-images-1.medium.com/max/800/1*670CdxchunD-yAuUWdI7Bw.png)
#
# Like the sigmoid function but more useful for multi-class classification problems. The softmax function can take any set of inputs and translate them into probabilities that sum up to 1. This means that we can throw any list of outputs at it and it will translate them into probabilities, this is extremely useful for multi-class classification problems. Like MNIST for example...

# %% [markdown]
# ### Major takeaways
#
# - ReLU is generally better at obtaining the optimal model fit.
# - Sigmoid and its derivatives are usually better at classification problems.
# - Softmax for multi-class classification problems.
#
# You'll typically see ReLU used for all initial layers and then the final layer being sigmoid or softmax for classification problems. But you can experiment and tune these selections as hyperparameters as well!

# %% [markdown]
# ## Challenge
#
# You will apply your choice of activation function inside two Keras Seqeuntial models today.
#
# ---

# %% [markdown]
# # Regularization Strategies (Learn)

# %% [markdown]
# ## Overview
#
# Neural Networks are highly parameterized models and can be easily overfit to the training data. The most salient way to combat this problem is with regularization strategies.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/0/02/Regularization.svg/1920px-Regularization.svg.png)
#
# There are four common ways of regularization in neural networks which we cover briefly. Here's a quick summary of how to apply them:
#
# 1. Always use EarlyStopping. This strategy will prevent your weights from being updated well past the point of their peak usefulness.
# 2. Use EarlyStopping, Weight Decay and Dropout
# 3. Use EarlyStopping, Weight Constraint and Dropout
#
# Weight Decay and Weigh Constraint accomplish similar purposes - preventing over fitting the parameters by regularizing the values. The mechanics are just slightly different. That's why you would not necessary want to apply them together.

# %% [markdown]
# ## Follow Along

# %% [markdown]
# ### Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

stop = EarlyStopping(monitor='val_accuracy', min_delta=0.01, patience=3)

model = Sequential([
    Flatten(),
    Dense(128, input_dim=784, activation='relu'),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='nadam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, 
          validation_data=(X_test,y_test),
          callbacks=[tensorboard_callback, stop])

# %% [markdown]
# ### Weight Decay
#
# ```python
# Dense(64, input_dim=64,
#             kernel_regularizer=regularizers.l2(0.01),
#             activity_regularizer=regularizers.l1(0.01)))
# ```

# %%
from tensorflow.keras import regularizers

# %% [markdown]
# ### Weight Constraint
#
# ```python
# tf.keras.constraints.MaxNorm(
#     max_value=2, axis=0
# )
# ```

# %%
from tensorflow.keras.constraints import MaxNorm

# %% [markdown]
# ### Dropout

# %%
from tensorflow.keras.layers import Dropout

# %%
# %tensorboard --logdir logs

# %% [markdown]
# ## Challenge
#
# You will apply regularization strategies inside your neural network today, as you try to avoid overfitting it.
#
# ---
